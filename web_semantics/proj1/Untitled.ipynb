# %%
#Ning and Zhang
#01 November 2019
#The Korea-China Special

from bs4 import BeautifulSoup
filepath = "./GPX_Tracks/GPX_Tracks/4sDDFdd4cjA.gpx"
fp = open(filepath, "r")
#need to update the filepath
soup = BeautifulSoup(fp, 'xml') #soupify the XML data

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <gpx creator="Visorando" version="1.1" xmlns="http://www.topografix.com/GPX/1/1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.topografix.com/GPX/1/1 http://www.topografix.com/GPX/1/1/gpx.xsd">
#  <metadata>
#   <name>
#    Refuge Maison Vieille - Refuge Bertone
#   </name>
#   <link href="https://www.visorando.com/randonnee-refuge-maison-vieille-refuge-bertone/">
#    <text>
#     https://www.visorando.com/randonnee-refuge-maison-vieille-refuge-bertone/
#    </text>
#   </link>
#  </metadata>
#  <wpt lat="45.790956" lon="6.931023">
#   <ele>
#    1954
#   </ele>
#   <time>
#    2019-10-23T13:46:57+02:00
#   </time>
#   <name>
#    Refuge de Maison Vieille
#   </name>
#  </wpt>
#  <wpt lat="45.792119" lon="6.945099">
#   <ele>
#    1741
#   </ele>
#   <time>
#    2019-10-23T13:47:52+02:00
#   </time>
#   <name>
#    Plan Chécrouit
#   </name>
#  </wpt>
#  <wpt lat="45.790058" lon="6.964475">
#   <ele>
# ...

# %%
print(soup.title)
# Out:
# None

# %%
print(soup.find_all('wpt'))
# Out:
# [<wpt lat="45.790956" lon="6.931023">
# <ele>1954</ele>
# <time>2019-10-23T13:46:57+02:00</time>
# <name>Refuge de Maison Vieille</name>
# </wpt>, <wpt lat="45.792119" lon="6.945099">
# <ele>1741</ele>
# <time>2019-10-23T13:47:52+02:00</time>
# <name>Plan Chécrouit</name>
# </wpt>, <wpt lat="45.790058" lon="6.964475">
# <ele>1213</ele>
# <time>2019-10-23T13:51:12+02:00</time>
# <name>Dolonne</name>
# </wpt>, <wpt lat="45.792164" lon="6.972329">
# <ele>1220</ele>
# <time>2019-10-23T13:52:12+02:00</time>
# <name>Courmayeur</name>
# </wpt>, <wpt lat="45.80077" lon="6.980547">
# <ele>1343</ele>
# <time>2019-10-23T13:53:02+02:00</time>
# <name>Villair-dessus</name>
# </wpt>, <wpt lat="45.803059" lon="6.985933">
# <ele>1453</ele>
# <time>2019-10-23T13:54:07+02:00</time>
# <name>Carrefour Bertone</name>
# </wpt>, <wpt lat="45.808638" lon="6.9778">
# <ele>1959</ele>
# <time>2019-10-23T13:55:52+02:00</time>
# <name>Refuge Bertone</name>
# </wpt>]

# %%
print(soup.find_all('trkpt'))
# Out:
# [<trkpt lat="45.790956" lon="6.931023">
# <ele>1954</ele>
# <time>2019-10-23T13:46:57+02:00</time>
# </trkpt>, <trkpt lat="45.790777" lon="6.932203">
# <ele>1950</ele>
# <time>2019-10-23T13:47:02+02:00</time>
# </trkpt>, <trkpt lat="45.791196" lon="6.932783">
# <ele>1955</ele>
# <time>2019-10-23T13:47:07+02:00</time>
# </trkpt>, <trkpt lat="45.791495" lon="6.935014">
# <ele>1920</ele>
# <time>2019-10-23T13:47:12+02:00</time>
# </trkpt>, <trkpt lat="45.793051" lon="6.936537">
# <ele>1893</ele>
# <time>2019-10-23T13:47:17+02:00</time>
# </trkpt>, <trkpt lat="45.792542" lon="6.937159">
# <ele>1875</ele>
# <time>2019-10-23T13:47:22+02:00</time>
# </trkpt>, <trkpt lat="45.792224" lon="6.937589">
# <ele>1862</ele>
# <time>2019-10-23T13:47:27+02:00</time>
# </trkpt>, <trkpt lat="45.79179" lon="6.93776">
# <ele>1851</ele>
# <time>2019-10-23T13:47:32+02:00</time>
# </trkpt>, <trkpt lat="45.791824" lon="6.939306">
# <ele>1819</ele>
# <time>2019-10-23T13:47:37+02:00</time>
# ...

# %%
test = soup.find_all("trkpt")
for item in test:
    print("Latitude: {0}\n Longitude: {1}\n Ele: {2}".format(item['lat'], item['lon'], item.ele.get_text()))
# Out:
# Latitude: 45.790956
#  Longitude: 6.931023
#  Ele: 1954
# Latitude: 45.790777
#  Longitude: 6.932203
#  Ele: 1950
# Latitude: 45.791196
#  Longitude: 6.932783
#  Ele: 1955
# Latitude: 45.791495
#  Longitude: 6.935014
#  Ele: 1920
# Latitude: 45.793051
#  Longitude: 6.936537
#  Ele: 1893
# Latitude: 45.792542
#  Longitude: 6.937159
#  Ele: 1875
# Latitude: 45.792224
#  Longitude: 6.937589
#  Ele: 1862
# Latitude: 45.79179
#  Longitude: 6.93776
#  Ele: 1851
# Latitude: 45.791824
#  Longitude: 6.939306
#  Ele: 1819
# Latitude: 45.792104
#  Longitude: 6.941322
#  Ele: 1800
# Latitude: 45.792254
#  Longitude: 6.943382
#  Ele: 1762
# Latitude: 45.792119
#  Longitude: 6.945099
#  Ele: 1741
# Latitude: 45.791525
#  Longitude: 6.945743
#  Ele: 1705
# Latitude: 45.790907
#  Longitude: 6.945313
#  Ele: 1692
# Latitude: 45.790717
#  Longitude: 6.945786
#  Ele: 1683
# Latitude: 45.790309
#  Longitude: 6.94512
#  Ele: 1681
# Latitude: 45.789729
#  Longitude: 6.944927
#  Ele: 1675
# ...

# %%
lon1 = 6.9778
lat1 = 45.808638
lon2 = 6.931023
lat2 = 45.790956

box_lon = abs(lon1-lon2)
box_lat = abs(lat1-lat2)

#define the box size
print(box_lon, box_lat)
# Out:
# 0.04677700000000051 0.01768200000000064

# %%
osm_file = open("osm_data_1.osm", "r")
osm_soup = BeautifulSoup(osm_file, "xml")

# %%
nodes = osm_soup.find_all("node")
for i in range(0, len(nodes)):
    if nodes[i].find("tag") == "aerialway":
        print(nodes[i], "yabai")

# %%
#the code snippet to get aerialway nodes
aerialway_nodes = []
for node in osm_soup.find_all("node"):
    if node.find_all(k="aerialway"):
        aerialway_nodes.append(node)
print(aerialway_nodes)
#NOTE: seems like these all contain tag k="name", so we should maybe isolate these and hash them into a dicionary?
# Out:
# [<node changeset="28222432" id="251790899" lat="45.7925897" lon="6.9638265" timestamp="2015-01-18T02:16:50Z" uid="1771944" user="dkwolf" version="4" visible="true">
# <tag k="aerialway" v="station"/>
# <tag k="ele:local" v="1211"/>
# <tag k="name" v="Dolonne"/>
# </node>, <node changeset="33700101" id="251791959" lat="45.7909264" lon="6.9462081" timestamp="2015-08-31T10:33:23Z" uid="2362150" user="Anonix35" version="6" visible="true">
# <tag k="aerialway" v="station"/>
# <tag k="aerialway:access" v="entry"/>
# <tag k="ele:local" v="1688"/>
# <tag k="name" v="Pra Neyron"/>
# </node>, <node changeset="28222388" id="251798920" lat="45.8004011" lon="6.9244199" timestamp="2015-01-18T02:09:29Z" uid="1771944" user="dkwolf" version="6" visible="true">
# <tag k="aerialway" v="station"/>
# <tag k="ele:local" v="1525"/>
# <tag k="name" v="Zerotta"/>
# ...

# %%
#this finds each node that has a name and hashes its data into a dictionary
nodes = {}
for node in osm_soup.find_all("node"):
    if node.tag != None:
        if node.find(k="name") != None:
            name = node.find(k="name").get("v")
            nodes[name] = node
print(nodes)
# Out:
# {'Dolonne': <node changeset="7139965" id="1128704605" lat="45.7922954" lon="6.9639752" timestamp="2011-01-30T21:28:19Z" uid="230707" user="stanton" version="1" visible="true">
# <tag k="highway" v="bus_stop"/>
# <tag k="name" v="Dolonne"/>
# <tag k="shelter" v="no"/>
# </node>, 'Pra Neyron': <node changeset="33700101" id="3307696399" lat="45.7939747" lon="6.9326830" timestamp="2015-08-31T10:33:24Z" uid="2362150" user="Anonix35" version="3" visible="true">
# <tag k="aerialway" v="station"/>
# <tag k="aerialway:access" v="exit"/>
# <tag k="ele:local" v="2035"/>
# <tag k="name" v="Pra Neyron"/>
# </node>, 'Zerotta': <node changeset="28222388" id="251798921" lat="45.7988031" lon="6.9396086" timestamp="2015-01-18T02:09:29Z" uid="1771944" user="dkwolf" version="4" visible="true">
# <tag k="aerialway" v="station"/>
# <tag k="ele:local" v="2080"/>
# <tag k="name" v="Zerotta"/>
# ...
